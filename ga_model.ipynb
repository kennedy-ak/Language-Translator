# %%
import pandas as pd

# Load the dataset
file_path = 'data-ga-en.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataset
print(data.head())
# Out:
#                      ga          english
# 0  Bo ni otswa mi aloo?  Did you call me
# 1  Bo ni otswa mi aloo?  Did you call me
# 2  Bo ni otswa mi aloo?  Did you call me
# 3  Bo ni otswa mi aloo?  Did you call me
# 4  Bo ni otswa mi aloo?  Did you call me

# %%
def preprocess_texts(texts):
    texts = texts.fillna('')  # Fill missing values
    texts = texts.str.lower()  # Convert to lower case
    texts = '<start> ' + texts + ' <end>'  # Add start and end tokens
    return texts

# Preprocess the texts
data['ga'] = preprocess_texts(data['ga'])
data['english'] = preprocess_texts(data['english'])

# Display the first few rows of the preprocessed data
print(data.head())
# Out:
#                                    ga                        english
# 0  <start> bo ni otswa mi aloo? <end>  <start> did you call me <end>
# 1  <start> bo ni otswa mi aloo? <end>  <start> did you call me <end>
# 2  <start> bo ni otswa mi aloo? <end>  <start> did you call me <end>
# 3  <start> bo ni otswa mi aloo? <end>  <start> did you call me <end>
# 4  <start> bo ni otswa mi aloo? <end>  <start> did you call me <end>

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Create a tokenizer for Twi texts
twi_tokenizer = Tokenizer()
twi_tokenizer.fit_on_texts(data['ga'])
twi_sequences = twi_tokenizer.texts_to_sequences(data['ga'])
twi_vocab_size = len(twi_tokenizer.word_index) + 1

# Create a tokenizer for English texts
english_tokenizer = Tokenizer()
english_tokenizer.fit_on_texts(data['english'])
english_sequences = english_tokenizer.texts_to_sequences(data['english'])
english_vocab_size = len(english_tokenizer.word_index) + 1

# Pad the sequences
max_len = max(max(len(seq) for seq in twi_sequences), max(len(seq) for seq in english_sequences))
twi_sequences = pad_sequences(twi_sequences, maxlen=max_len, padding='post')
english_sequences = pad_sequences(english_sequences, maxlen=max_len, padding='post')

# %%
import numpy as np

# Prepare encoder input data
encoder_input_data = np.array(twi_sequences)

# Prepare decoder input and output data
decoder_input_data = np.array(english_sequences)
decoder_output_data = np.zeros_like(decoder_input_data)

# Shift the decoder output data by one timestep
decoder_output_data[:, :-1] = decoder_input_data[:, 1:]
decoder_output_data[:, -1] = 0

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding

# Define model parameters
embedding_dim = 256
latent_dim = 512

# Encoder
encoder_inputs = Input(shape=(None,))
encoder_embedding = Embedding(twi_vocab_size, embedding_dim)(encoder_inputs)
encoder_lstm, state_h, state_c = LSTM(latent_dim, return_state=True)(encoder_embedding)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(None,))
decoder_embedding = Embedding(english_vocab_size, embedding_dim)(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)
decoder_dense = Dense(english_vocab_size, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')

# Train the model
batch_size = 64
epochs = 100

model.fit([encoder_input_data, decoder_input_data],
          np.expand_dims(decoder_output_data, -1),
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2)
# Out:
# Epoch 1/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - loss: 1.4434 - val_loss: 1.6216
# Epoch 2/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.5006 - val_loss: 1.9937
# Epoch 3/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.2222 - val_loss: 2.3180
# Epoch 4/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.1313 - val_loss: 2.5101
# Epoch 5/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0707 - val_loss: 2.6415
# Epoch 6/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0336 - val_loss: 2.7904
# Epoch 7/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0245 - val_loss: 2.8613
# Epoch 8/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0069 - val_loss: 2.9288
# Epoch 9/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0025 - val_loss: 2.9917
# Epoch 10/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0020 - val_loss: 3.0331
# Epoch 11/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0019 - val_loss: 3.0679
# Epoch 12/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0018 - val_loss: 3.0975
# Epoch 13/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0017 - val_loss: 3.1208
# Epoch 14/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0016 - val_loss: 3.1426
# Epoch 15/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0014 - val_loss: 3.1614
# Epoch 16/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 0.0015 - val_loss: 3.1801
# Epoch 17/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0014 - val_loss: 3.1950
# Epoch 18/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0014 - val_loss: 3.2086
# Epoch 19/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0015 - val_loss: 3.2231
# Epoch 20/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0013 - val_loss: 3.2349
# Epoch 21/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0014 - val_loss: 3.2469
# Epoch 22/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0014 - val_loss: 3.2581
# Epoch 23/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0014 - val_loss: 3.2691
# Epoch 24/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0014 - val_loss: 3.2783
# Epoch 25/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0015 - val_loss: 3.2878
# Epoch 26/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0013 - val_loss: 3.2958
# Epoch 27/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0014 - val_loss: 3.3044
# Epoch 28/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0013 - val_loss: 3.3125
# Epoch 29/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0013 - val_loss: 3.3202
# Epoch 30/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0013 - val_loss: 3.3273
# Epoch 31/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0013 - val_loss: 3.3346
# Epoch 32/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0012 - val_loss: 3.3412
# Epoch 33/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0012 - val_loss: 3.3480
# Epoch 34/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0012 - val_loss: 3.3537
# Epoch 35/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0013 - val_loss: 3.3606
# Epoch 36/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0011 - val_loss: 3.3658
# Epoch 37/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0012 - val_loss: 3.3715
# Epoch 38/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0012 - val_loss: 3.3772
# Epoch 39/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0011 - val_loss: 3.3832
# Epoch 40/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0013 - val_loss: 3.3881
# Epoch 41/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0013 - val_loss: 3.3922
# Epoch 42/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0011 - val_loss: 3.3975
# Epoch 43/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0012 - val_loss: 3.4023
# Epoch 44/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0013 - val_loss: 3.4064
# Epoch 45/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0012 - val_loss: 3.4114
# Epoch 46/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0012 - val_loss: 3.4159
# Epoch 47/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0012 - val_loss: 3.4197
# Epoch 48/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0012 - val_loss: 3.4242
# Epoch 49/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0012 - val_loss: 3.4285
# Epoch 50/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0012 - val_loss: 3.4325
# Epoch 51/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0011 - val_loss: 3.4361
# Epoch 52/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0011 - val_loss: 3.4400
# Epoch 53/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0011 - val_loss: 3.4439
# Epoch 54/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0012 - val_loss: 3.4476
# Epoch 55/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0011 - val_loss: 3.4514
# Epoch 56/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0012 - val_loss: 3.4549
# Epoch 57/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0012 - val_loss: 3.4586
# Epoch 58/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0011 - val_loss: 3.4619
# Epoch 59/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0012 - val_loss: 3.4649
# Epoch 60/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0012 - val_loss: 3.4682
# Epoch 61/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - loss: 0.0012 - val_loss: 3.4713
# Epoch 62/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0011 - val_loss: 3.4744
# Epoch 63/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0011 - val_loss: 3.4775
# Epoch 64/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0012 - val_loss: 3.4804
# Epoch 65/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0011 - val_loss: 3.4836
# Epoch 66/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0012 - val_loss: 3.4867
# Epoch 67/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0011 - val_loss: 3.4896
# Epoch 68/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0012 - val_loss: 3.4919
# Epoch 69/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0012 - val_loss: 3.4951
# Epoch 70/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0012 - val_loss: 3.4977
# Epoch 71/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0011 - val_loss: 3.5005
# Epoch 72/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0011 - val_loss: 3.5032
# Epoch 73/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0012 - val_loss: 3.5053
# Epoch 74/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0011 - val_loss: 3.5079
# Epoch 75/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0013 - val_loss: 3.5108
# Epoch 76/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0011 - val_loss: 3.5132
# Epoch 77/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0011 - val_loss: 3.5157
# Epoch 78/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0011 - val_loss: 3.5179
# Epoch 79/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0011 - val_loss: 3.5202
# Epoch 80/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0011 - val_loss: 3.5229
# Epoch 81/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0012 - val_loss: 3.5247
# Epoch 82/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0010 - val_loss: 3.5270
# Epoch 83/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0012 - val_loss: 3.5294
# Epoch 84/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0012 - val_loss: 3.5317
# Epoch 85/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0011 - val_loss: 3.5335
# Epoch 86/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0011 - val_loss: 3.5355
# Epoch 87/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0012 - val_loss: 3.5380
# Epoch 88/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0012 - val_loss: 3.5404
# Epoch 89/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0011 - val_loss: 3.5423
# Epoch 90/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 0.0011 - val_loss: 3.5441
# Epoch 91/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0011 - val_loss: 3.5466
# Epoch 92/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0012 - val_loss: 3.5486
# Epoch 93/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0010 - val_loss: 3.5505
# Epoch 94/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0011 - val_loss: 3.5517
# Epoch 95/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0011 - val_loss: 3.5540
# Epoch 96/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0011 - val_loss: 3.5561
# Epoch 97/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0011 - val_loss: 3.5578
# Epoch 98/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0010 - val_loss: 3.5594
# Epoch 99/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 0.0011 - val_loss: 3.5620
# Epoch 100/100
# 307/307 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.0011 - val_loss: 3.5635

# %%
model.save("fine-tuned-translation-model.keras")
twi_tokenizer_json = twi_tokenizer.to_json()
english_tokenizer_json = english_tokenizer.to_json()

with open("ga_tokenizer.json", "w") as f:
    f.write(twi_tokenizer_json)

with open("english_tokenizer.json", "w") as f:
    f.write(english_tokenizer_json)

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.text import tokenizer_from_json
import json

# Load the model
model = load_model("fine-tuned-translation-model.keras")

# Load the tokenizers
with open("ga_tokenizer.json") as f:
    twi_tokenizer_json = json.load(f)
    twi_tokenizer = tokenizer_from_json(json.dumps(twi_tokenizer_json))

with open("english_tokenizer.json") as f:
    english_tokenizer_json = json.load(f)
    english_tokenizer = tokenizer_from_json(json.dumps(english_tokenizer_json))

def translate_twi_to_english(twi_sentence):
    # Preprocess the sentence
    twi_sentence = preprocess_texts(pd.Series([twi_sentence]))[0]

    # Tokenize the Twi sentence
    tokenized_text = twi_tokenizer.texts_to_sequences([twi_sentence])
    tokenized_text = pad_sequences(tokenized_text, maxlen=max_len, padding='post')

    # Generate translation
    translated = model.predict([tokenized_text, np.zeros_like(tokenized_text)])

    # Decode the generated translation
    translated_sentence = english_tokenizer.sequences_to_texts(np.argmax(translated, axis=-1))[0]

    return translated_sentence.replace('<start> ', '').replace(' <end>', '')

# Example translation
twi_sentence = "Ani nakai lo"
translated_sentence = translate_twi_to_english(twi_sentence)
print(f"Twi: {twi_sentence}\nEnglish: {translated_sentence}")
